# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# ...

# %%
plt.rc('font', family='NanumBarunGothic')

# %%
df1 = pd.read_excel("consumer.fix.xlsx")
df1
# Out:
#                     C(B)SI코드별 C(B)SI분류코드별  2018.02  2019.02  2020.02  2021.02  \
# 0                　　　현재생활형편CSI          전체       94       93       91       87
# 1                　　　현재경기판단CSI          전체       89       70       66       63
# 2                　　　생활형편전망CSI          전체      102       92       93       94
# 3                　　　향후경기전망CSI          전체       98       80       76       90
# 4                　　　취업기회전망CSI          전체       93       79       81       80
# 5                　　　금리수준전망CSI          전체      128      120       92      104
# 6                　　　가계수입전망CSI          전체      103       98       97       96
# 7                　　　소비지출전망CSI          전체      108      109      106      104
# 8           　　　　　　내구재 지출전망CSI          전체       97       95       93       91
# 9           　　　　　　의류비 지출전망CSI          전체      102       96       95       92
# 10          　　　　　　외식비 지출전망CSI          전체       94       89       89       88
# ...

# %%
df2 = pd.read_excel("company_trend.sales_performance.xlsx")
df2
# Out:
#            C(B)SI코드별 C(B)SI분류코드별  2018.02  2019.02  2020.02  2021.02  2022.02
# 0                전산업      매출실적2)       86       78       70       81       94
# 1             　　　제조업      매출실적2)       83       80       71       91      102
# 2          　　　　　　식료품      매출실적2)       99       93       81       85      100
# 3           　　　　　　음료      매출실적2)      100       83       77       71       87
# 4           　　　　　　섬유      매출실적2)       65       56       54       59       83
# 5         　　　　　　의복모피      매출실적2)       85       82       66       66      113
# 6     　　　　　　가죽・가방・신발      매출실적2)       65       65       46       54       96
# 7        　　　　　　목재・나무      매출실적2)       67       59       57       75       91
# 8        　　　　　　펄프・종이      매출실적2)       93       96      100       96       93
# 9    　　　　　　인쇄・기록매체복제      매출실적2)       78       74       71       73       91
# 10    　　　　　　석유정제・코크스      매출실적2)       64       79       52       56      112
# ...

# %%
df3 = pd.read_excel("startup.xlsx")
df3
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                     업종별(1)                     업종별(2)  2018.02 2018.02.1  \
# 0                   업종별(1)                     업종별(2)       전체        법인
# 1                       합계                         소계  96519.0    7411.0
# 2                      NaN                     기술기반업종  15903.0    2866.0
# 3         농업, 임업 및 어업 및 광업                         소계    877.0     196.0
# 4                      제조업                         소계   4304.0    1065.0
# 5                      NaN                  음식료품 및 음료    567.0     110.0
# 6                      NaN                    섬유 및 가죽    521.0      75.0
# 7                      NaN              목재, 가구 및 종이제품    266.0      50.0
# 8                      NaN              인쇄 및 기록매체 복제업    113.0      17.0
# ...

# %%
_df2=df2.loc[[45]]
_df2.drop('C(B)SI분류코드별',axis=1,inplace=True)
_df2.set_index("C(B)SI코드별",inplace=True)
_df2.T
# Out:
# C(B)SI코드별  　　　　　　예술・스포츠・여가
# 2018.02                 48
# 2019.02                 83
# 2020.02                 65
# 2021.02                 68
# 2022.02                103

# %%
_df2.T.plot(marker='o',markersize=7)
plt.title("예술, 스포츠 및 여가관련 서비스업" , fontsize=20)
plt.xlabel('연도',fontsize = 15)
plt.ylabel('BSI',fontsize=15)

plt.plot()
# Out:
# []
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 12539 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 12539 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
_df3=df3[['업종별(2)','2018.02',	'2019.02',		'2020.02',		'2021.02',		'2022.02']	]
_df3_1=_df3.loc[[28]]
_df3_1.set_index('업종별(2)',inplace=True)
_df3_1.T
# Out:
# 업종별(2)   예술, 스포츠 및 여가관련 서비스업
# 2018.02               2368.0
# 2019.02               2280.0
# 2020.02               2373.0
# 2021.02               1901.0
# 2022.02               1885.0

# %%
_df3_1.T.plot(marker='o',markersize=7)
plt.title("예술, 스포츠 및 여가관련 서비스업" , fontsize=20)
plt.xlabel('연도',fontsize = 15)
plt.ylabel('CSI',fontsize=15)
plt.plot()
# Out:
# []

# %%
_df2.T.plot(marker='o',markersize=7)
plt.title("예술, 스포츠 및 여가관련 서비스업BSI" , fontsize=20)
plt.xlabel('연도',fontsize = 15)
plt.ylabel('BSI',fontsize=15)

_df3_1.T.plot(marker='o',markersize=7)
plt.title("예술, 스포츠 및 여가관련 서비스업 창업수" , fontsize=20)
plt.xlabel('연도',fontsize = 15)
plt.ylabel('CSI',fontsize=15)

plt.plot()
# Out:
# []
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 12539 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 12539 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df1_1= df1.loc[[11]]
df1_1.set_index("C(B)SI코드별",inplace=True)
df1_1
# Out:
#                   C(B)SI분류코드별  2018.02  2019.02  2020.02  2021.02  2022.02
# C(B)SI코드별
# 　　　　　　여행비 지출전망CSI          전체       96       89       83       76       89

# %%
df2_1= df2.loc[[39]]
df2_1.set_index("C(B)SI코드별",inplace=True)
df2_1
# Out:
#           C(B)SI분류코드별  2018.02  2019.02  2020.02  2021.02  2022.02
# C(B)SI코드별
# 　　　　　　숙박업      매출실적2)       72       59       30       21      102

# %%
an1=pd.concat([df1_1,df2_1])
an1
# Out:
#                   C(B)SI분류코드별  2018.02  2019.02  2020.02  2021.02  2022.02
# C(B)SI코드별
# 　　　　　　여행비 지출전망CSI          전체       96       89       83       76       89
# 　　　　　　숙박업              매출실적2)       72       59       30       21      102

# %%
an2=an1.drop(['C(B)SI분류코드별'],axis=1)
an2
# Out:
#                    2018.02  2019.02  2020.02  2021.02  2022.02
# C(B)SI코드별
# 　　　　　　여행비 지출전망CSI       96       89       83       76       89
# 　　　　　　숙박업               72       59       30       21      102

# %%
an3=an2.T
an3
# Out:
# C(B)SI코드별  　　　　　　여행비 지출전망CSI  　　　　　　숙박업
# 2018.02                   96         72
# 2019.02                   89         59
# 2020.02                   83         30
# 2021.02                   76         21
# 2022.02                   89        102

# %%
an3.plot(kind='bar',color=['green','blue'])
plt.title("여행비 지출&숙박업 매출C(B)SI" , fontsize=30)
plt.xlabel('연도',fontsize = 20)
plt.ylabel('CSI',fontsize=20)

plt.show()

# %%
an3.plot(marker='o',markersize=7)
plt.title("여행비 지출CSI&숙박업 매출BSI" , fontsize=20)
plt.xlabel('연도',fontsize = 15)
plt.ylabel('CSI',fontsize=15)

plt.plot()
# Out:
# []

# %%
df3_1=df3.loc[[20]]
df3_1
# Out:
#    업종별(1)      업종별(2)  2018.02 2018.02.1 2018.02.2  2019.02 2019.02.1  \
# 20    NaN   숙박 및 음식점업  12254.0     106.0   12148.0  12689.0     108.0
#
#    2019.02.2  2020.02 2020.02.1 2020.02.2  2021.02 2021.02.1 2021.02.2  \
# 20   12581.0  13805.0     124.0   13681.0  10796.0      89.0   10707.0
#
#    2022.02 2022.02.1 2022.02.2
# 20  9596.0     121.0    9475.0

# %%
individual=pd.Series([106,108,124,89,121],
                     index=['2018','2019','2020','2021','2022'])
company=pd.Series([12148,12581,13681,9596,9457],
                     index=['2018','2019','2020','2021','2022'])
all=pd.Series([12254,12689,13805,10796,9596],
                     index=['2018','2019','2020','2021','2022'])  
df3_2=pd.DataFrame({'개인':individual,
                     '기업':company,
                    "전체":all})
df3_2
# Out:
#        개인     기업     전체
# 2018  106  12148  12254
# 2019  108  12581  12689
# 2020  124  13681  13805
# 2021   89   9596  10796
# 2022  121   9457   9596

# %%
quantity=[106,12148]
quality=['개인','기업']
plt.pie(quantity,labels=quality,startangle=0,autopct='%.1f%%',explode=(0,0.5))
plt.title("2018개인&기업별 창업수",fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
quantity=[108,12581]
quality=['개인','기업']
plt.pie(quantity,labels=quality,startangle=0,autopct='%.1f%%',explode=(0,0.5))
plt.title("2019개인&기업별 창업수",fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
quantity=[124,13681]
quality=['개인','기업']
plt.pie(quantity,labels=quality,startangle=0,autopct='%.1f%%',explode=(0,0.5))
plt.title("2020개인&기업별 창업수",fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
quantity=[189,9596]
quality=['개인','기업']
plt.pie(quantity,labels=quality,startangle=0,autopct='%.1f%%',explode=(0,0.5))
plt.title("2021개인&기업별 창업수",fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
quantity=[121,9417]
quality=['개인','기업']
plt.pie(quantity,labels=quality,startangle=0,autopct='%.1f%%',explode=(0,0.5))
plt.title("2022개인&기업별 창업수",fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
df3_3=df3_2[['전체']]
df3_3
# Out:
#          전체
# 2018  12254
# 2019  12689
# 2020  13805
# 2021  10796
# 2022   9596

# %%
df3_3.plot(marker='o',markersize=7)
plt.title("숙박 및 음식점업 창업수 증가률" , fontsize=20)
plt.xlabel('연도',fontsize = 15)
plt.ylabel('창업수',fontsize=15)

plt.plot()
# Out:
# []

# %%
an3.plot(marker='o',markersize=7)
plt.title("여행비 지출CSI&숙박업 매출BSI" , fontsize=20)
plt.xlabel('연도',fontsize = 15)
plt.ylabel('CSI',fontsize=15)

df3_3.plot(marker='o',markersize=7)
plt.title("숙박 및 음식점업 창업수 증가률" , fontsize=20)
plt.xlabel('연도',fontsize = 15)
plt.ylabel('창업수',fontsize=15)

plt.plot()
# Out:
# []
